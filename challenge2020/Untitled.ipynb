# %%
import sys
sys.path.append(r'c:\users\administrator\appdata\local\programs\python\python37\lib\site-packages')
from models.inceptiontime import Classifier_INCEPTION
from keras.callbacks import TensorBoard
import scipy.io as scio
import pandas as pd
import wfdb
from keras.models import Model
import os
import tensorflow.keras as keras
from utils.loss import my_loss, f1
model = Classifier_INCEPTION(bottleneck_size=32, depth=6, kernel_size=40, nb_filters=32, type='inceptiontime_v2',head_dropout_rate=0.5).model
adam = keras.optimizers.Adam(lr=0.001)
model.compile(optimizer=adam,
              loss= 'categorical_crossentropy',
              metrics=['accuracy',f1])
model.summary()
model.load_weights('./result/result-inceptiontime/best_model.hdf5')
# Out:
# Model: "model_7"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_8 (InputLayer)            [(None, 43200, 12)]  0
# __________________________________________________________________________________________________
# conv1d_434 (Conv1D)             (None, 43200, 32)    384         input_8[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_84 (MaxPooling1D) (None, 21600, 12)    0           input_8[0][0]
# __________________________________________________________________________________________________
# conv1d_435 (Conv1D)             (None, 21600, 32)    39936       conv1d_434[0][0]
# __________________________________________________________________________________________________
# conv1d_436 (Conv1D)             (None, 21600, 32)    19456       conv1d_434[0][0]
# __________________________________________________________________________________________________
# conv1d_437 (Conv1D)             (None, 21600, 32)    9216        conv1d_434[0][0]
# __________________________________________________________________________________________________
# conv1d_438 (Conv1D)             (None, 21600, 32)    384         max_pooling1d_84[0][0]
# __________________________________________________________________________________________________
# concatenate_84 (Concatenate)    (None, 21600, 128)   0           conv1d_435[0][0]
#                                                                  conv1d_436[0][0]
#                                                                  conv1d_437[0][0]
#                                                                  conv1d_438[0][0]
# __________________________________________________________________________________________________
# batch_normalization_98 (BatchNo (None, 21600, 128)   512         concatenate_84[0][0]
# __________________________________________________________________________________________________
# activation_98 (Activation)      (None, 21600, 128)   0           batch_normalization_98[0][0]
# __________________________________________________________________________________________________
# conv1d_439 (Conv1D)             (None, 21600, 32)    4096        activation_98[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_85 (MaxPooling1D) (None, 21600, 128)   0           activation_98[0][0]
# __________________________________________________________________________________________________
# conv1d_440 (Conv1D)             (None, 21600, 32)    39936       conv1d_439[0][0]
# __________________________________________________________________________________________________
# conv1d_441 (Conv1D)             (None, 21600, 32)    19456       conv1d_439[0][0]
# __________________________________________________________________________________________________
# conv1d_442 (Conv1D)             (None, 21600, 32)    9216        conv1d_439[0][0]
# __________________________________________________________________________________________________
# conv1d_443 (Conv1D)             (None, 21600, 32)    4096        max_pooling1d_85[0][0]
# __________________________________________________________________________________________________
# concatenate_85 (Concatenate)    (None, 21600, 128)   0           conv1d_440[0][0]
#                                                                  conv1d_441[0][0]
#                                                                  conv1d_442[0][0]
#                                                                  conv1d_443[0][0]
# __________________________________________________________________________________________________
# batch_normalization_99 (BatchNo (None, 21600, 128)   512         concatenate_85[0][0]
# __________________________________________________________________________________________________
# activation_99 (Activation)      (None, 21600, 128)   0           batch_normalization_99[0][0]
# __________________________________________________________________________________________________
# conv1d_444 (Conv1D)             (None, 21600, 32)    4096        activation_99[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_86 (MaxPooling1D) (None, 10800, 128)   0           activation_99[0][0]
# __________________________________________________________________________________________________
# conv1d_445 (Conv1D)             (None, 10800, 32)    39936       conv1d_444[0][0]
# __________________________________________________________________________________________________
# conv1d_446 (Conv1D)             (None, 10800, 32)    19456       conv1d_444[0][0]
# __________________________________________________________________________________________________
# conv1d_447 (Conv1D)             (None, 10800, 32)    9216        conv1d_444[0][0]
# __________________________________________________________________________________________________
# conv1d_448 (Conv1D)             (None, 10800, 32)    4096        max_pooling1d_86[0][0]
# __________________________________________________________________________________________________
# concatenate_86 (Concatenate)    (None, 10800, 128)   0           conv1d_445[0][0]
#                                                                  conv1d_446[0][0]
#                                                                  conv1d_447[0][0]
#                                                                  conv1d_448[0][0]
# __________________________________________________________________________________________________
# batch_normalization_100 (BatchN (None, 10800, 128)   512         concatenate_86[0][0]
# __________________________________________________________________________________________________
# activation_100 (Activation)     (None, 10800, 128)   0           batch_normalization_100[0][0]
# __________________________________________________________________________________________________
# conv1d_449 (Conv1D)             (None, 10800, 32)    4096        activation_100[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_87 (MaxPooling1D) (None, 10800, 128)   0           activation_100[0][0]
# __________________________________________________________________________________________________
# conv1d_450 (Conv1D)             (None, 10800, 32)    39936       conv1d_449[0][0]
# __________________________________________________________________________________________________
# conv1d_451 (Conv1D)             (None, 10800, 32)    19456       conv1d_449[0][0]
# __________________________________________________________________________________________________
# conv1d_452 (Conv1D)             (None, 10800, 32)    9216        conv1d_449[0][0]
# __________________________________________________________________________________________________
# conv1d_453 (Conv1D)             (None, 10800, 32)    4096        max_pooling1d_87[0][0]
# __________________________________________________________________________________________________
# concatenate_87 (Concatenate)    (None, 10800, 128)   0           conv1d_450[0][0]
#                                                                  conv1d_451[0][0]
#                                                                  conv1d_452[0][0]
#                                                                  conv1d_453[0][0]
# __________________________________________________________________________________________________
# batch_normalization_101 (BatchN (None, 10800, 128)   512         concatenate_87[0][0]
# __________________________________________________________________________________________________
# activation_101 (Activation)     (None, 10800, 128)   0           batch_normalization_101[0][0]
# __________________________________________________________________________________________________
# conv1d_454 (Conv1D)             (None, 10800, 32)    4096        activation_101[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_88 (MaxPooling1D) (None, 5400, 128)    0           activation_101[0][0]
# __________________________________________________________________________________________________
# conv1d_455 (Conv1D)             (None, 5400, 32)     39936       conv1d_454[0][0]
# __________________________________________________________________________________________________
# conv1d_456 (Conv1D)             (None, 5400, 32)     19456       conv1d_454[0][0]
# __________________________________________________________________________________________________
# conv1d_457 (Conv1D)             (None, 5400, 32)     9216        conv1d_454[0][0]
# __________________________________________________________________________________________________
# conv1d_458 (Conv1D)             (None, 5400, 32)     4096        max_pooling1d_88[0][0]
# __________________________________________________________________________________________________
# concatenate_88 (Concatenate)    (None, 5400, 128)    0           conv1d_455[0][0]
#                                                                  conv1d_456[0][0]
#                                                                  conv1d_457[0][0]
#                                                                  conv1d_458[0][0]
# __________________________________________________________________________________________________
# batch_normalization_102 (BatchN (None, 5400, 128)    512         concatenate_88[0][0]
# __________________________________________________________________________________________________
# activation_102 (Activation)     (None, 5400, 128)    0           batch_normalization_102[0][0]
# __________________________________________________________________________________________________
# conv1d_459 (Conv1D)             (None, 5400, 32)     4096        activation_102[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_89 (MaxPooling1D) (None, 5400, 128)    0           activation_102[0][0]
# __________________________________________________________________________________________________
# conv1d_460 (Conv1D)             (None, 5400, 32)     39936       conv1d_459[0][0]
# __________________________________________________________________________________________________
# conv1d_461 (Conv1D)             (None, 5400, 32)     19456       conv1d_459[0][0]
# __________________________________________________________________________________________________
# conv1d_462 (Conv1D)             (None, 5400, 32)     9216        conv1d_459[0][0]
# __________________________________________________________________________________________________
# conv1d_463 (Conv1D)             (None, 5400, 32)     4096        max_pooling1d_89[0][0]
# __________________________________________________________________________________________________
# concatenate_89 (Concatenate)    (None, 5400, 128)    0           conv1d_460[0][0]
#                                                                  conv1d_461[0][0]
#                                                                  conv1d_462[0][0]
#                                                                  conv1d_463[0][0]
# __________________________________________________________________________________________________
# conv1d_464 (Conv1D)             (None, 5400, 128)    1536        input_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_103 (BatchN (None, 5400, 128)    512         concatenate_89[0][0]
# __________________________________________________________________________________________________
# batch_normalization_104 (BatchN (None, 5400, 128)    512         conv1d_464[0][0]
# __________________________________________________________________________________________________
# activation_103 (Activation)     (None, 5400, 128)    0           batch_normalization_103[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 5400, 128)    0           batch_normalization_104[0][0]
#                                                                  activation_103[0][0]
# __________________________________________________________________________________________________
# activation_104 (Activation)     (None, 5400, 128)    0           add_14[0][0]
# __________________________________________________________________________________________________
# conv1d_465 (Conv1D)             (None, 5400, 32)     4096        activation_104[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_90 (MaxPooling1D) (None, 2700, 128)    0           activation_104[0][0]
# __________________________________________________________________________________________________
# conv1d_466 (Conv1D)             (None, 2700, 32)     39936       conv1d_465[0][0]
# __________________________________________________________________________________________________
# conv1d_467 (Conv1D)             (None, 2700, 32)     19456       conv1d_465[0][0]
# __________________________________________________________________________________________________
# conv1d_468 (Conv1D)             (None, 2700, 32)     9216        conv1d_465[0][0]
# __________________________________________________________________________________________________
# conv1d_469 (Conv1D)             (None, 2700, 32)     4096        max_pooling1d_90[0][0]
# __________________________________________________________________________________________________
# concatenate_90 (Concatenate)    (None, 2700, 128)    0           conv1d_466[0][0]
#                                                                  conv1d_467[0][0]
#                                                                  conv1d_468[0][0]
#                                                                  conv1d_469[0][0]
# __________________________________________________________________________________________________
# batch_normalization_105 (BatchN (None, 2700, 128)    512         concatenate_90[0][0]
# __________________________________________________________________________________________________
# activation_105 (Activation)     (None, 2700, 128)    0           batch_normalization_105[0][0]
# __________________________________________________________________________________________________
# conv1d_470 (Conv1D)             (None, 2700, 32)     4096        activation_105[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_91 (MaxPooling1D) (None, 2700, 128)    0           activation_105[0][0]
# __________________________________________________________________________________________________
# conv1d_471 (Conv1D)             (None, 2700, 32)     39936       conv1d_470[0][0]
# __________________________________________________________________________________________________
# conv1d_472 (Conv1D)             (None, 2700, 32)     19456       conv1d_470[0][0]
# __________________________________________________________________________________________________
# conv1d_473 (Conv1D)             (None, 2700, 32)     9216        conv1d_470[0][0]
# __________________________________________________________________________________________________
# conv1d_474 (Conv1D)             (None, 2700, 32)     4096        max_pooling1d_91[0][0]
# __________________________________________________________________________________________________
# concatenate_91 (Concatenate)    (None, 2700, 128)    0           conv1d_471[0][0]
#                                                                  conv1d_472[0][0]
#                                                                  conv1d_473[0][0]
#                                                                  conv1d_474[0][0]
# __________________________________________________________________________________________________
# batch_normalization_106 (BatchN (None, 2700, 128)    512         concatenate_91[0][0]
# __________________________________________________________________________________________________
# activation_106 (Activation)     (None, 2700, 128)    0           batch_normalization_106[0][0]
# __________________________________________________________________________________________________
# conv1d_475 (Conv1D)             (None, 2700, 32)     4096        activation_106[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_92 (MaxPooling1D) (None, 1350, 128)    0           activation_106[0][0]
# __________________________________________________________________________________________________
# conv1d_476 (Conv1D)             (None, 1350, 32)     39936       conv1d_475[0][0]
# __________________________________________________________________________________________________
# conv1d_477 (Conv1D)             (None, 1350, 32)     19456       conv1d_475[0][0]
# __________________________________________________________________________________________________
# conv1d_478 (Conv1D)             (None, 1350, 32)     9216        conv1d_475[0][0]
# __________________________________________________________________________________________________
# conv1d_479 (Conv1D)             (None, 1350, 32)     4096        max_pooling1d_92[0][0]
# __________________________________________________________________________________________________
# concatenate_92 (Concatenate)    (None, 1350, 128)    0           conv1d_476[0][0]
#                                                                  conv1d_477[0][0]
#                                                                  conv1d_478[0][0]
#                                                                  conv1d_479[0][0]
# __________________________________________________________________________________________________
# batch_normalization_107 (BatchN (None, 1350, 128)    512         concatenate_92[0][0]
# __________________________________________________________________________________________________
# activation_107 (Activation)     (None, 1350, 128)    0           batch_normalization_107[0][0]
# __________________________________________________________________________________________________
# conv1d_480 (Conv1D)             (None, 1350, 32)     4096        activation_107[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_93 (MaxPooling1D) (None, 1350, 128)    0           activation_107[0][0]
# __________________________________________________________________________________________________
# conv1d_481 (Conv1D)             (None, 1350, 32)     39936       conv1d_480[0][0]
# __________________________________________________________________________________________________
# conv1d_482 (Conv1D)             (None, 1350, 32)     19456       conv1d_480[0][0]
# __________________________________________________________________________________________________
# conv1d_483 (Conv1D)             (None, 1350, 32)     9216        conv1d_480[0][0]
# __________________________________________________________________________________________________
# conv1d_484 (Conv1D)             (None, 1350, 32)     4096        max_pooling1d_93[0][0]
# __________________________________________________________________________________________________
# concatenate_93 (Concatenate)    (None, 1350, 128)    0           conv1d_481[0][0]
#                                                                  conv1d_482[0][0]
#                                                                  conv1d_483[0][0]
#                                                                  conv1d_484[0][0]
# __________________________________________________________________________________________________
# batch_normalization_108 (BatchN (None, 1350, 128)    512         concatenate_93[0][0]
# __________________________________________________________________________________________________
# activation_108 (Activation)     (None, 1350, 128)    0           batch_normalization_108[0][0]
# __________________________________________________________________________________________________
# conv1d_485 (Conv1D)             (None, 1350, 32)     4096        activation_108[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_94 (MaxPooling1D) (None, 675, 128)     0           activation_108[0][0]
# __________________________________________________________________________________________________
# conv1d_486 (Conv1D)             (None, 675, 32)      39936       conv1d_485[0][0]
# __________________________________________________________________________________________________
# conv1d_487 (Conv1D)             (None, 675, 32)      19456       conv1d_485[0][0]
# __________________________________________________________________________________________________
# conv1d_488 (Conv1D)             (None, 675, 32)      9216        conv1d_485[0][0]
# __________________________________________________________________________________________________
# conv1d_489 (Conv1D)             (None, 675, 32)      4096        max_pooling1d_94[0][0]
# __________________________________________________________________________________________________
# concatenate_94 (Concatenate)    (None, 675, 128)     0           conv1d_486[0][0]
#                                                                  conv1d_487[0][0]
#                                                                  conv1d_488[0][0]
#                                                                  conv1d_489[0][0]
# __________________________________________________________________________________________________
# batch_normalization_109 (BatchN (None, 675, 128)     512         concatenate_94[0][0]
# __________________________________________________________________________________________________
# activation_109 (Activation)     (None, 675, 128)     0           batch_normalization_109[0][0]
# __________________________________________________________________________________________________
# conv1d_490 (Conv1D)             (None, 675, 32)      4096        activation_109[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_95 (MaxPooling1D) (None, 675, 128)     0           activation_109[0][0]
# __________________________________________________________________________________________________
# conv1d_491 (Conv1D)             (None, 675, 32)      39936       conv1d_490[0][0]
# __________________________________________________________________________________________________
# conv1d_492 (Conv1D)             (None, 675, 32)      19456       conv1d_490[0][0]
# __________________________________________________________________________________________________
# conv1d_493 (Conv1D)             (None, 675, 32)      9216        conv1d_490[0][0]
# __________________________________________________________________________________________________
# conv1d_494 (Conv1D)             (None, 675, 32)      4096        max_pooling1d_95[0][0]
# __________________________________________________________________________________________________
# concatenate_95 (Concatenate)    (None, 675, 128)     0           conv1d_491[0][0]
#                                                                  conv1d_492[0][0]
#                                                                  conv1d_493[0][0]
#                                                                  conv1d_494[0][0]
# __________________________________________________________________________________________________
# conv1d_495 (Conv1D)             (None, 675, 128)     16384       activation_104[0][0]
# __________________________________________________________________________________________________
# batch_normalization_110 (BatchN (None, 675, 128)     512         concatenate_95[0][0]
# __________________________________________________________________________________________________
# batch_normalization_111 (BatchN (None, 675, 128)     512         conv1d_495[0][0]
# __________________________________________________________________________________________________
# activation_110 (Activation)     (None, 675, 128)     0           batch_normalization_110[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 675, 128)     0           batch_normalization_111[0][0]
#                                                                  activation_110[0][0]
# __________________________________________________________________________________________________
# activation_111 (Activation)     (None, 675, 128)     0           add_15[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_7 (Glo (None, 128)          0           activation_111[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 128)          0           global_average_pooling1d_7[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 9)            1161        dropout_7[0][0]
# ==================================================================================================
# Total params: 940,425
# Trainable params: 936,841
# Non-trainable params: 3,584
# __________________________________________________________________________________________________
# Model: "model_7"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_8 (InputLayer)            [(None, 43200, 12)]  0
# __________________________________________________________________________________________________
# conv1d_434 (Conv1D)             (None, 43200, 32)    384         input_8[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_84 (MaxPooling1D) (None, 21600, 12)    0           input_8[0][0]
# __________________________________________________________________________________________________
# conv1d_435 (Conv1D)             (None, 21600, 32)    39936       conv1d_434[0][0]
# __________________________________________________________________________________________________
# conv1d_436 (Conv1D)             (None, 21600, 32)    19456       conv1d_434[0][0]
# __________________________________________________________________________________________________
# conv1d_437 (Conv1D)             (None, 21600, 32)    9216        conv1d_434[0][0]
# __________________________________________________________________________________________________
# conv1d_438 (Conv1D)             (None, 21600, 32)    384         max_pooling1d_84[0][0]
# __________________________________________________________________________________________________
# concatenate_84 (Concatenate)    (None, 21600, 128)   0           conv1d_435[0][0]
#                                                                  conv1d_436[0][0]
#                                                                  conv1d_437[0][0]
#                                                                  conv1d_438[0][0]
# __________________________________________________________________________________________________
# batch_normalization_98 (BatchNo (None, 21600, 128)   512         concatenate_84[0][0]
# __________________________________________________________________________________________________
# activation_98 (Activation)      (None, 21600, 128)   0           batch_normalization_98[0][0]
# __________________________________________________________________________________________________
# conv1d_439 (Conv1D)             (None, 21600, 32)    4096        activation_98[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_85 (MaxPooling1D) (None, 21600, 128)   0           activation_98[0][0]
# __________________________________________________________________________________________________
# conv1d_440 (Conv1D)             (None, 21600, 32)    39936       conv1d_439[0][0]
# __________________________________________________________________________________________________
# conv1d_441 (Conv1D)             (None, 21600, 32)    19456       conv1d_439[0][0]
# __________________________________________________________________________________________________
# conv1d_442 (Conv1D)             (None, 21600, 32)    9216        conv1d_439[0][0]
# __________________________________________________________________________________________________
# conv1d_443 (Conv1D)             (None, 21600, 32)    4096        max_pooling1d_85[0][0]
# __________________________________________________________________________________________________
# concatenate_85 (Concatenate)    (None, 21600, 128)   0           conv1d_440[0][0]
#                                                                  conv1d_441[0][0]
#                                                                  conv1d_442[0][0]
#                                                                  conv1d_443[0][0]
# __________________________________________________________________________________________________
# batch_normalization_99 (BatchNo (None, 21600, 128)   512         concatenate_85[0][0]
# __________________________________________________________________________________________________
# activation_99 (Activation)      (None, 21600, 128)   0           batch_normalization_99[0][0]
# __________________________________________________________________________________________________
# conv1d_444 (Conv1D)             (None, 21600, 32)    4096        activation_99[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_86 (MaxPooling1D) (None, 10800, 128)   0           activation_99[0][0]
# __________________________________________________________________________________________________
# conv1d_445 (Conv1D)             (None, 10800, 32)    39936       conv1d_444[0][0]
# __________________________________________________________________________________________________
# conv1d_446 (Conv1D)             (None, 10800, 32)    19456       conv1d_444[0][0]
# __________________________________________________________________________________________________
# conv1d_447 (Conv1D)             (None, 10800, 32)    9216        conv1d_444[0][0]
# __________________________________________________________________________________________________
# conv1d_448 (Conv1D)             (None, 10800, 32)    4096        max_pooling1d_86[0][0]
# __________________________________________________________________________________________________
# concatenate_86 (Concatenate)    (None, 10800, 128)   0           conv1d_445[0][0]
#                                                                  conv1d_446[0][0]
#                                                                  conv1d_447[0][0]
#                                                                  conv1d_448[0][0]
# __________________________________________________________________________________________________
# batch_normalization_100 (BatchN (None, 10800, 128)   512         concatenate_86[0][0]
# __________________________________________________________________________________________________
# activation_100 (Activation)     (None, 10800, 128)   0           batch_normalization_100[0][0]
# __________________________________________________________________________________________________
# conv1d_449 (Conv1D)             (None, 10800, 32)    4096        activation_100[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_87 (MaxPooling1D) (None, 10800, 128)   0           activation_100[0][0]
# __________________________________________________________________________________________________
# conv1d_450 (Conv1D)             (None, 10800, 32)    39936       conv1d_449[0][0]
# __________________________________________________________________________________________________
# conv1d_451 (Conv1D)             (None, 10800, 32)    19456       conv1d_449[0][0]
# __________________________________________________________________________________________________
# conv1d_452 (Conv1D)             (None, 10800, 32)    9216        conv1d_449[0][0]
# __________________________________________________________________________________________________
# conv1d_453 (Conv1D)             (None, 10800, 32)    4096        max_pooling1d_87[0][0]
# __________________________________________________________________________________________________
# concatenate_87 (Concatenate)    (None, 10800, 128)   0           conv1d_450[0][0]
#                                                                  conv1d_451[0][0]
#                                                                  conv1d_452[0][0]
#                                                                  conv1d_453[0][0]
# __________________________________________________________________________________________________
# batch_normalization_101 (BatchN (None, 10800, 128)   512         concatenate_87[0][0]
# __________________________________________________________________________________________________
# activation_101 (Activation)     (None, 10800, 128)   0           batch_normalization_101[0][0]
# __________________________________________________________________________________________________
# conv1d_454 (Conv1D)             (None, 10800, 32)    4096        activation_101[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_88 (MaxPooling1D) (None, 5400, 128)    0           activation_101[0][0]
# __________________________________________________________________________________________________
# conv1d_455 (Conv1D)             (None, 5400, 32)     39936       conv1d_454[0][0]
# __________________________________________________________________________________________________
# conv1d_456 (Conv1D)             (None, 5400, 32)     19456       conv1d_454[0][0]
# __________________________________________________________________________________________________
# conv1d_457 (Conv1D)             (None, 5400, 32)     9216        conv1d_454[0][0]
# __________________________________________________________________________________________________
# conv1d_458 (Conv1D)             (None, 5400, 32)     4096        max_pooling1d_88[0][0]
# __________________________________________________________________________________________________
# concatenate_88 (Concatenate)    (None, 5400, 128)    0           conv1d_455[0][0]
#                                                                  conv1d_456[0][0]
#                                                                  conv1d_457[0][0]
#                                                                  conv1d_458[0][0]
# __________________________________________________________________________________________________
# batch_normalization_102 (BatchN (None, 5400, 128)    512         concatenate_88[0][0]
# __________________________________________________________________________________________________
# activation_102 (Activation)     (None, 5400, 128)    0           batch_normalization_102[0][0]
# __________________________________________________________________________________________________
# conv1d_459 (Conv1D)             (None, 5400, 32)     4096        activation_102[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_89 (MaxPooling1D) (None, 5400, 128)    0           activation_102[0][0]
# __________________________________________________________________________________________________
# conv1d_460 (Conv1D)             (None, 5400, 32)     39936       conv1d_459[0][0]
# __________________________________________________________________________________________________
# conv1d_461 (Conv1D)             (None, 5400, 32)     19456       conv1d_459[0][0]
# __________________________________________________________________________________________________
# conv1d_462 (Conv1D)             (None, 5400, 32)     9216        conv1d_459[0][0]
# __________________________________________________________________________________________________
# conv1d_463 (Conv1D)             (None, 5400, 32)     4096        max_pooling1d_89[0][0]
# __________________________________________________________________________________________________
# concatenate_89 (Concatenate)    (None, 5400, 128)    0           conv1d_460[0][0]
#                                                                  conv1d_461[0][0]
#                                                                  conv1d_462[0][0]
#                                                                  conv1d_463[0][0]
# __________________________________________________________________________________________________
# conv1d_464 (Conv1D)             (None, 5400, 128)    1536        input_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_103 (BatchN (None, 5400, 128)    512         concatenate_89[0][0]
# __________________________________________________________________________________________________
# batch_normalization_104 (BatchN (None, 5400, 128)    512         conv1d_464[0][0]
# __________________________________________________________________________________________________
# activation_103 (Activation)     (None, 5400, 128)    0           batch_normalization_103[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 5400, 128)    0           batch_normalization_104[0][0]
#                                                                  activation_103[0][0]
# __________________________________________________________________________________________________
# activation_104 (Activation)     (None, 5400, 128)    0           add_14[0][0]
# __________________________________________________________________________________________________
# conv1d_465 (Conv1D)             (None, 5400, 32)     4096        activation_104[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_90 (MaxPooling1D) (None, 2700, 128)    0           activation_104[0][0]
# __________________________________________________________________________________________________
# conv1d_466 (Conv1D)             (None, 2700, 32)     39936       conv1d_465[0][0]
# __________________________________________________________________________________________________
# conv1d_467 (Conv1D)             (None, 2700, 32)     19456       conv1d_465[0][0]
# __________________________________________________________________________________________________
# conv1d_468 (Conv1D)             (None, 2700, 32)     9216        conv1d_465[0][0]
# __________________________________________________________________________________________________
# conv1d_469 (Conv1D)             (None, 2700, 32)     4096        max_pooling1d_90[0][0]
# __________________________________________________________________________________________________
# concatenate_90 (Concatenate)    (None, 2700, 128)    0           conv1d_466[0][0]
#                                                                  conv1d_467[0][0]
#                                                                  conv1d_468[0][0]
#                                                                  conv1d_469[0][0]
# __________________________________________________________________________________________________
# batch_normalization_105 (BatchN (None, 2700, 128)    512         concatenate_90[0][0]
# __________________________________________________________________________________________________
# activation_105 (Activation)     (None, 2700, 128)    0           batch_normalization_105[0][0]
# __________________________________________________________________________________________________
# conv1d_470 (Conv1D)             (None, 2700, 32)     4096        activation_105[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_91 (MaxPooling1D) (None, 2700, 128)    0           activation_105[0][0]
# __________________________________________________________________________________________________
# conv1d_471 (Conv1D)             (None, 2700, 32)     39936       conv1d_470[0][0]
# __________________________________________________________________________________________________
# conv1d_472 (Conv1D)             (None, 2700, 32)     19456       conv1d_470[0][0]
# __________________________________________________________________________________________________
# conv1d_473 (Conv1D)             (None, 2700, 32)     9216        conv1d_470[0][0]
# __________________________________________________________________________________________________
# conv1d_474 (Conv1D)             (None, 2700, 32)     4096        max_pooling1d_91[0][0]
# __________________________________________________________________________________________________
# concatenate_91 (Concatenate)    (None, 2700, 128)    0           conv1d_471[0][0]
#                                                                  conv1d_472[0][0]
#                                                                  conv1d_473[0][0]
#                                                                  conv1d_474[0][0]
# __________________________________________________________________________________________________
# batch_normalization_106 (BatchN (None, 2700, 128)    512         concatenate_91[0][0]
# __________________________________________________________________________________________________
# activation_106 (Activation)     (None, 2700, 128)    0           batch_normalization_106[0][0]
# __________________________________________________________________________________________________
# conv1d_475 (Conv1D)             (None, 2700, 32)     4096        activation_106[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_92 (MaxPooling1D) (None, 1350, 128)    0           activation_106[0][0]
# __________________________________________________________________________________________________
# conv1d_476 (Conv1D)             (None, 1350, 32)     39936       conv1d_475[0][0]
# __________________________________________________________________________________________________
# conv1d_477 (Conv1D)             (None, 1350, 32)     19456       conv1d_475[0][0]
# __________________________________________________________________________________________________
# conv1d_478 (Conv1D)             (None, 1350, 32)     9216        conv1d_475[0][0]
# __________________________________________________________________________________________________
# conv1d_479 (Conv1D)             (None, 1350, 32)     4096        max_pooling1d_92[0][0]
# __________________________________________________________________________________________________
# concatenate_92 (Concatenate)    (None, 1350, 128)    0           conv1d_476[0][0]
#                                                                  conv1d_477[0][0]
#                                                                  conv1d_478[0][0]
#                                                                  conv1d_479[0][0]
# __________________________________________________________________________________________________
# batch_normalization_107 (BatchN (None, 1350, 128)    512         concatenate_92[0][0]
# __________________________________________________________________________________________________
# activation_107 (Activation)     (None, 1350, 128)    0           batch_normalization_107[0][0]
# __________________________________________________________________________________________________
# conv1d_480 (Conv1D)             (None, 1350, 32)     4096        activation_107[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_93 (MaxPooling1D) (None, 1350, 128)    0           activation_107[0][0]
# __________________________________________________________________________________________________
# conv1d_481 (Conv1D)             (None, 1350, 32)     39936       conv1d_480[0][0]
# __________________________________________________________________________________________________
# conv1d_482 (Conv1D)             (None, 1350, 32)     19456       conv1d_480[0][0]
# __________________________________________________________________________________________________
# conv1d_483 (Conv1D)             (None, 1350, 32)     9216        conv1d_480[0][0]
# __________________________________________________________________________________________________
# conv1d_484 (Conv1D)             (None, 1350, 32)     4096        max_pooling1d_93[0][0]
# __________________________________________________________________________________________________
# concatenate_93 (Concatenate)    (None, 1350, 128)    0           conv1d_481[0][0]
#                                                                  conv1d_482[0][0]
#                                                                  conv1d_483[0][0]
#                                                                  conv1d_484[0][0]
# __________________________________________________________________________________________________
# batch_normalization_108 (BatchN (None, 1350, 128)    512         concatenate_93[0][0]
# __________________________________________________________________________________________________
# activation_108 (Activation)     (None, 1350, 128)    0           batch_normalization_108[0][0]
# __________________________________________________________________________________________________
# conv1d_485 (Conv1D)             (None, 1350, 32)     4096        activation_108[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_94 (MaxPooling1D) (None, 675, 128)     0           activation_108[0][0]
# __________________________________________________________________________________________________
# conv1d_486 (Conv1D)             (None, 675, 32)      39936       conv1d_485[0][0]
# __________________________________________________________________________________________________
# conv1d_487 (Conv1D)             (None, 675, 32)      19456       conv1d_485[0][0]
# __________________________________________________________________________________________________
# conv1d_488 (Conv1D)             (None, 675, 32)      9216        conv1d_485[0][0]
# __________________________________________________________________________________________________
# conv1d_489 (Conv1D)             (None, 675, 32)      4096        max_pooling1d_94[0][0]
# __________________________________________________________________________________________________
# concatenate_94 (Concatenate)    (None, 675, 128)     0           conv1d_486[0][0]
#                                                                  conv1d_487[0][0]
#                                                                  conv1d_488[0][0]
#                                                                  conv1d_489[0][0]
# __________________________________________________________________________________________________
# batch_normalization_109 (BatchN (None, 675, 128)     512         concatenate_94[0][0]
# __________________________________________________________________________________________________
# activation_109 (Activation)     (None, 675, 128)     0           batch_normalization_109[0][0]
# __________________________________________________________________________________________________
# conv1d_490 (Conv1D)             (None, 675, 32)      4096        activation_109[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_95 (MaxPooling1D) (None, 675, 128)     0           activation_109[0][0]
# __________________________________________________________________________________________________
# conv1d_491 (Conv1D)             (None, 675, 32)      39936       conv1d_490[0][0]
# __________________________________________________________________________________________________
# conv1d_492 (Conv1D)             (None, 675, 32)      19456       conv1d_490[0][0]
# __________________________________________________________________________________________________
# conv1d_493 (Conv1D)             (None, 675, 32)      9216        conv1d_490[0][0]
# __________________________________________________________________________________________________
# conv1d_494 (Conv1D)             (None, 675, 32)      4096        max_pooling1d_95[0][0]
# __________________________________________________________________________________________________
# concatenate_95 (Concatenate)    (None, 675, 128)     0           conv1d_491[0][0]
#                                                                  conv1d_492[0][0]
#                                                                  conv1d_493[0][0]
#                                                                  conv1d_494[0][0]
# __________________________________________________________________________________________________
# conv1d_495 (Conv1D)             (None, 675, 128)     16384       activation_104[0][0]
# __________________________________________________________________________________________________
# batch_normalization_110 (BatchN (None, 675, 128)     512         concatenate_95[0][0]
# __________________________________________________________________________________________________
# batch_normalization_111 (BatchN (None, 675, 128)     512         conv1d_495[0][0]
# __________________________________________________________________________________________________
# activation_110 (Activation)     (None, 675, 128)     0           batch_normalization_110[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 675, 128)     0           batch_normalization_111[0][0]
#                                                                  activation_110[0][0]
# __________________________________________________________________________________________________
# activation_111 (Activation)     (None, 675, 128)     0           add_15[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_7 (Glo (None, 128)          0           activation_111[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 128)          0           global_average_pooling1d_7[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 9)            1161        dropout_7[0][0]
# ==================================================================================================
# Total params: 940,425
# Trainable params: 936,841
# Non-trainable params: 3,584
# __________________________________________________________________________________________________

# %%
data1 = scio.loadmat('../fixed_length_data'+str('/')+'A0002')['val'].T
data1 = data1.reshape(1,43200,12)

# %%
ypred = model.predict(data1)

# %%
ypred
# Out:
# array([[1.6780834e-05, 7.1749448e-05, 1.8417146e-06, 9.4788986e-01,
#         3.2570340e-02, 1.0295612e-02, 2.0629638e-07, 7.7388128e-03,
#         1.4147343e-03]], dtype=float32)

# %%
layer_model=model(inputs=model.input,outputs=model.layers[3].output)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-39b76f1b40ca> in <module>
# ----> 1 layer_model=model(inputs=model.input,outputs=model.layers[3].output)
#
# c:\users\administrator\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\keras\engine\base_layer.py in __call__(self, inputs, *args, **kwargs)
#     632                     outputs = base_layer_utils.mark_as_return(outputs, acd)
#     633                 else:
# --> 634                   outputs = call_fn(inputs, *args, **kwargs)
#     635
#     636             except TypeError as e:
#
# TypeError: call() got an unexpected keyword argument 'outputs'

# %%
model.layers[3]

# %%
def readname(filePath):
    name = os.listdir(filePath)
    return name
file_colletion = readname('../resample_data'+str('/'))
dat_collection = []
for i in range(0,len(file_colletion)):
    if file_colletion[i].find('.mat')>=0:
        dat_collection.append(file_colletion[i].strip('.mat'))
deep_feature = pd.DataFrame(columns=['D1','D2','D3','D4','D5','D6','D7','D8','D9'])
for j in range(0,len(dat_collection)):
    print(dat_collection[j])
    record = wfdb.rdrecord('../resample_data'+str('/')+dat_collection[j].strip('.mat'))
    data_temp = pd.DataFrame(columns=['D1','D2','D3','D4','D5','D6','D7','D8','D9'],data = model.predict(scio.loadmat('../fixed_length_data'+str('/')+dat_collection[j])['val'].T.reshape(1,43200,12)).tolist())
    if  ',' not in record.__dict__['comments'][2][4:]:
        deep_feature = deep_feature.append(data_temp)
    else:
        s = record.__dict__['comments'][2][4:]
        s += '0'
        while len(s) != 0:
            ans = ''
            for k in range(len(s)):
                if s[k] != ',' and s[k] != '0':
                    ans += s[k]
                elif s[k] == ',':
                    s = s[k + 1:]
                    break
                elif s[k] == '0':
                    s = ''
            deep_feature = deep_feature.append(data_temp)
deep_feature.to_csv('DEEP_FEATURE.csv', sep=',', header=True, index=False)
# Out:
# A0001
# A0002
# A0003
# A0004
# A0005
# A0006
# A0007
# A0008
# A0009
# A0010
# A0011
# A0012
# A0013
# A0014
# A0015
# A0016
# A0017
# A0018
# A0019
# A0020
# A0021
# A0022
# A0023
# A0024
# A0025
# A0026
# A0027
# A0028
# A0029
# A0030
# A0031
# A0032
# A0033
# A0034
# A0035
# A0036
# A0037
# A0038
# A0039
# A0040
# A0041
# A0042
# A0043
# A0044
# A0045
# A0046
# A0047
# A0048
# A0049
# A0050
# A0051
# A0052
# A0053
# A0054
# A0055
# A0056
# A0057
# A0058
# A0059
# A0060
# A0061
# A0062
# A0063
# A0064
# A0065
# A0066
# A0067
# A0068
# A0069
# A0070
# A0071
# A0072
# A0073
# A0074
# A0075
# A0076
# A0077
# A0078
# A0079
# A0080
# A0081
# A0082
# A0083
# A0084
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-49-904186fe2cbe> in <module>
#      11     print(dat_collection[j])
#      12     record = wfdb.rdrecord('../resample_data'+str('/')+dat_collection[j].strip('.mat'))
# ---> 13     data_temp = pd.DataFrame(columns=['D1','D2','D3','D4','D5','D6','D7','D8','D9'],data = model.predict(scio.loadmat('../fixed_length_data'+str('/')+dat_collection[j])['val'].T.reshape(1,43200,12)).tolist())
#      14     if  ',' not in record.__dict__['comments'][2][4:]:
#      15         deep_feature = deep_feature.append(data_temp)
#
# c:\users\administrator\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\keras\engine\training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1076           verbose=verbose,
#    1077           steps=steps,
# -> 1078           callbacks=callbacks)
#    1079
#    1080   def reset_metrics(self):
#
# c:\users\administrator\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\keras\engine\training_arrays.py in model_iteration(model, inputs, targets, sample_weights, batch_size, epochs, verbose, callbacks, val_inputs, val_targets, val_sample_weights, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq, mode, validation_in_fit, prepared_feed_values_from_dataset, steps_name, **kwargs)
#     361
#     362         # Get outputs.
# --> 363         batch_outs = f(ins_batch)
#     364         if not isinstance(batch_outs, list):
#     365           batch_outs = [batch_outs]
#
# c:\users\administrator\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\keras\backend.py in __call__(self, inputs)
#    3290
#    3291     fetched = self._callable_fn(*array_vals,
# -> 3292                                 run_metadata=self.run_metadata)
#    3293     self._call_fetch_callbacks(fetched[-len(self._fetches):])
#    3294     output_structure = nest.pack_sequence_as(
#
# c:\users\administrator\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\client\session.py in __call__(self, *args, **kwargs)
#    1456         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1457                                                self._handle, args,
# -> 1458                                                run_metadata_ptr)
#    1459         if run_metadata:
#    1460           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
dat_collection
# Out:
# ['A0001',
#  'A0002',
#  'A0003',
#  'A0004',
#  'A0005',
#  'A0006',
#  'A0007',
#  'A0008',
#  'A0009',
#  'A0010',
#  'A0011',
#  'A0012',
#  'A0013',
#  'A0014',
#  'A0015',
#  'A0016',
#  'A0017',
#  'A0018',
#  'A0019',
#  'A0020',
#  'A0021',
#  'A0022',
#  'A0023',
#  'A0024',
#  'A0025',
#  'A0026',
#  'A0027',
#  'A0028',
#  'A0029',
#  'A0030',
#  'A0031',
#  'A0032',
#  'A0033',
#  'A0034',
#  'A0035',
#  'A0036',
#  'A0037',
#  'A0038',
#  'A0039',
#  'A0040',
#  'A0041',
#  'A0042',
#  'A0043',
#  'A0044',
#  'A0045',
#  'A0046',
#  'A0047',
#  'A0048',
#  'A0049',
#  'A0050',
#  'A0051',
#  'A0052',
#  'A0053',
#  'A0054',
#  'A0055',
#  'A0056',
#  'A0057',
#  'A0058',
#  'A0059',
#  'A0060',
#  'A0061',
#  'A0062',
#  'A0063',
#  'A0064',
#  'A0065',
#  'A0066',
#  'A0067',
#  'A0068',
#  'A0069',
#  'A0070',
#  'A0071',
#  'A0072',
#  'A0073',
#  'A0074',
#  'A0075',
#  'A0076',
#  'A0077',
#  'A0857',
#  'A0858',
#  'A0859',
#  'A0860',
#  'A0861',
#  'A0862',
#  'A0863',
#  'A0864',
#  'A0865',
#  'A0866',
#  'A0867',
#  'A0868',
#  'A0869',
#  'A0870',
#  'A0871',
#  'A0872',
#  'A0873',
#  'A0874',
#  'A0875',
#  'A0876',
#  'A0877',
#  'A0878',
#  'A0879',
#  'A0880',
#  'A0881',
#  'A0882',
#  'A0883',
#  'A0884',
#  'A0885',
#  'A0886',
#  'A0887',
#  'A0888',
#  'A0889',
#  'A0890',
#  'A0891',
#  'A0892',
#  'A0893',
#  'A0894',
#  'A0895',
#  'A0896',
#  'A0897',
#  'A0898',
#  'A0899',
#  'A0900',
#  'A0901',
#  'A0902',
#  'A0903',
#  'A0904',
#  'A0905',
#  'A0906',
#  'A0907',
#  'A0908',
#  'A0909',
#  'A0910',
#  'A0911',
#  'A0912',
#  'A0913',
#  'A0914',
#  'A0915',
#  'A0916',
#  'A0917',
#  'A0918',
#  'A0919',
#  'A0920',
#  'A0921',
#  'A0922',
#  'A0923',
#  'A0924',
#  'A0925',
#  'A0926',
#  'A0927',
#  'A0928',
#  'A0929',
#  'A0930',
#  'A0931',
#  'A0932',
#  'A0933',
#  'A0934',
#  'A0935',
#  'A0936',
#  'A0937',
#  'A0938',
#  'A0939',
#  'A0940',
#  'A0941',
#  'A0942',
#  'A0943',
#  'A0944',
#  'A0945',
#  'A0946',
#  'A0947',
#  'A0948',
#  'A0949',
#  'A0950',
#  'A0951',
#  'A0952',
#  'A0953',
#  'A0954',
#  'A0955',
#  'A0956',
#  'A0957',
#  'A0958',
#  'A0959',
#  'A0960',
#  'A0961',
#  'A0962',
#  'A0963',
#  'A0964',
#  'A0965',
#  'A0966',
#  'A0967',
#  'A0968',
#  'A0969',
#  'A0970',
#  'A0971',
#  'A0972',
#  'A0973',
#  'A0974',
#  'A0975',
#  'A0976',
#  'A0977',
#  'A0978',
#  'A0979',
#  'A0980',
#  'A0981',
#  'A0982',
#  'A0983',
#  'A0984',
#  'A0985',
#  'A0986',
#  'A0987',
#  'A0988',
#  'A0989',
#  'A0990',
#  'A0991',
#  'A0992',
#  'A0993',
#  'A0994',
#  'A0995',
#  'A0996',
#  'A0997',
#  'A0998',
#  'A0999',
#  'A1000',
#  ...]

# %%
import pandas as pd
deep_feature = pd.DataFrame(columns=['D1','D2','D3','D4','D5','D6','D7','D8','D9'])

# %%
deep_feature.append(temp_data)
# Out:
#          D1        D2        D3            D4        D5        D6        D7  \
# 0  0.002062  0.000037  0.000043  2.606303e-07  0.001602  0.012101  0.983859
#
#          D8        D9
# 0  0.000243  0.000052

# %%
temp_data = pd.DataFrame(columns=['D1','D2','D3','D4','D5','D6','D7','D8','D9'],data = ypred.tolist())

# %%
temp_data
# Out:
#          D1        D2        D3            D4        D5        D6        D7  \
# 0  0.002062  0.000037  0.000043  2.606303e-07  0.001602  0.012101  0.983859
#
#          D8        D9
# 0  0.000243  0.000052

# %%
deep_feature
# Out:
# Empty DataFrame
# Columns: [D1, D2, D3, D4, D5, D6, D7, D8, D9]
# Index: []
